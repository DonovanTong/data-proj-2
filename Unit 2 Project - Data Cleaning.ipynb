# %% [markdown]
# # Unit 2 Project - Data Cleaning

# %% [markdown]
# ## Part 1: Prepare Environment and Jupyter Notebook

# %% [markdown]
# ### Step 1: Create Virtual Environment
#
# This step should have been completed prior to opening the Jupyter Notebook. Refer to project instructions.

# %% [markdown]
# ### Step 2: Open Jupyter Notebook File
#
# Congratulations! If you're here it means you have completed Step 2.

# %% [markdown]
# ### Step 3: Load .csv Files into DataFrames

# %%
####### TO DO ########
import pandas as pd
import seaborn as sns
# load house_data.csv into a dataframe using pd.read_csv()
house_df = pd.read_csv('house_data.csv')
# load house_sales.csv into a dataframe using pd.read_csv()
sales_df = pd.read_csv('house_sales.csv')
######################

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was loaded succussfully
house_df.head()
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
# ...

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was loaded succussfully
sales_df.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %% [markdown]
# ### Step 4: Create Data Dictionaries for Each Dataset

# %%
####### TO DO ###########

# Work in the cells below to fill in missing information in the data dictionary.

# %% [markdown]
# #### Data Dictionary - House Data
#
# **id**:
# > Description: House ID, Auto generated
# >
# > Data type: Integer
#
# **bedrooms**:
# > Description: Number of bedrooms in house
# >
# > Data type: Integer
#
# **bathrooms**:
# > Description: Number of bathrooms in house
# >
# > Data type: Decimal
#
# **sqft_living**:
# > Description: Area of House's interior in square feet
# >
# > Data type: Float
#
# **sqft_lot**:
# > Description: Area of house's property in square feet
# >
# > Data type: Float
#
# **floors**:
# > Description: Amount of separate levels in a home
# >
# > Data type: Float
#
# **waterfront**:
# > Description: Description of whether or not the house's lot is next to a body of water.
# >
# > Data type: String
#
# **view**:
# > Description: Quality of view from the house
# >
# > Data type: String
#
# **condition**:
# > Description: Quality of house cosmetically
# >
# > Data type: String
#
# **grade**:
# > Description: Quality of construction in form of rating out of ten
# >
# > Data type: Float
#
# **sqft_above**:
# > Description: Amount of area in square feet above ground
# >
# > Data type: Float
#
# **sqft_basement**:
# > Description: Amount of area in square feet below ground
# >
# > Data type: Integer
#
# **yr_built**:
# > Description: Year when house was constructed
# >
# > Data type: Integer
#
# **yr_renovated**:
# > Description: Year when house was renovated (if applicable)
# >
# > Data type: Float
#
# **zipcode**:
# > Description: House's zipcode
# >
# > Data type: Float
#
# **lat**:
# > Description: Houses lattitudinal coordinates
# >
# > Data type: Float
#
# **long**:
# > Description: House's longitudinal coordinates
# >
# > Data type: Float
#
# **sqft_living15**:
# > Description: Average house square footage 15 closest houses
# >
# > Data type: Integer
#
# **sqft_lot15**:
# > Description: Average size in square feet of the 15 closest houses
# >
# > Data type: Integer

# %% [markdown]
# #### Data Dictionary - House Sales Data
#
# **id**:
# > Description: Sale ID
# >
# > Data type: Integer
#
# **date**:
# > Description: Date of sale
# >
# > Data type: String
#
# **price**:
# > Description: Price that house was sold for
# >
# > Data type: String

# %% [markdown]
# ### Step 5: Create Copies of DataFrames to Start Cleaning Process

# %%
###### TO DO ######

# create a copy of house_data
houseDf = house_df.copy()
# create a copy of sales_data
salesDf = sales_df.copy()

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was copied succussfully
houseDf.head()
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
# ...

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was copied succussfully
salesDf.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %% [markdown]
# ## Part 2: Assess Data and Create Data Cleaning Plan

# %% [markdown]
# ### Step 1: Check Column Names, Casing, Spelling, Etc.

# %%
######################### TO DO ###################################
houseDf.info()
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
# ...

# %% [markdown]
# ### Step 2: Validate Data Types

# %%
######################### TO DO ###################################
salesDf.info()
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21613 non-null  int64
#  1   Id          21613 non-null  int64
#  2   DATE        21613 non-null  object
#  3   Price       21609 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 675.5+ KB

# %% [markdown]
# Q: Do any of the data types in the dataframe need to be changed?

# %% [markdown]
# A: #### TO DO #####
# Yes, the zipcode and the ID need to be strings (objects).

# %% [markdown]
# ### Step 3: Detect Missing Values

# %%
######################### TO DO ###################################
houseDf.isna().sum()
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
# ID                   0
# Bedrooms             0
# Bathrooms            2
# SQFT living          0
# SQFT lot             2
# Floors               0
# Waterfront?          8
# View                 2
# House Condition      6
# Grade                2
# SQFT above           1
# SQFT basement        0
# Year Built           1
# Year Renovated     337
# Zipcode              3
# Lat                  1
# Long                 1
# SQFT living 15       0
# SQFT lot 15          0
# dtype: int64

# %% [markdown]
# Q: Which variables/columns have missing values?

# %% [markdown]
# A: ##### TO DO #####
# for houseDF: bathrooms, sqft_lot, waterfront, view, condition, grade, sqft_above, yr_built, yr_renovated, zipcode, lat, long.
#     for salesDF: price.

# %% [markdown]
# ### Step 4: Detect Outliers

# %%
######################### TO DO ###################################
sns.boxplot(data=houseDf["SQFT lot 15"])
houseDf["SQFT lot 15"].describe()
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
# count    2.161300e+04
# mean     1.343592e+04
# std      1.018656e+05
# min      6.510000e+02
# 25%      5.100000e+03
# 50%      7.620000e+03
# 75%      1.008300e+04
# max      1.444040e+07
# Name: SQFT lot 15, dtype: float64

# %% [markdown]
# Q: Which variables/columns have outliers?

# %% [markdown]
# A: ##### TO DO #####
# Bedrooms(Max 33), Bathrooms(max 10), SQFT lot, SQFT above(Max 12000), SQFT basement(Max 4800), Year Built(Min 1000, Max 2050), SQFT lot 15

# %% [markdown]
# ### Step 5: Write Data Cleaning Plan

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# #### Data Cleaning Plan:
#
# First, the zipcode and the ID need to be changed from numbers to strings/objects. Then, the columns with missing values need to be changed or deleted depending on how much data is missing. The "Unnamed: 0" column needs to be deleted as well as the "Year Renovated" column. The following are missing data: Bathrooms, SQFT lot, Waterfront, View, Condition, Grade, SQFT above, Year Built, Year Renovated, Zipcode, Lat, Long, and Price.

# %% [markdown]
# ## Part 3: Execute Data Cleaning Plan Using DEFINE / CLEAN / TEST Approach

# %% [markdown]
# ### Step 1: Understand DEFINE / CLEAN / TEST Approach

# %% [markdown]
# Refer to project instructions for an explanation of this step. You can copy and past the template in the cell below to use in each step of Part 3 as you are treating the issues you found in the data.

# %%
### DEFINE ###


### CLEAN ### 


### TEST ###

# %% [markdown]
# ### Step 2: Treat Names / Casing / Spelling Issues

# %%
######################### TO DO ###################################
houseDf.head()
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
# ...

# %%
salesDf.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %%
salesDf.isna().sum()
# Out:
# Unnamed: 0    0
# Id            0
# DATE          0
# Price         4
# dtype: int64

# %%
### DEFINE ###
#The Unnamed: 0 column needs to be dropped

### CLEAN ### 
salesDf.drop(columns=['Unnamed: 0'], inplace=True)

### TEST ###
salesDf.head()
# Out:
#            Id             DATE        Price
# 0  7129300520  20141013T000000  $221,900.00
# 1  6414100192  20141209T000000  $538,000.00
# 2  5631500400  20150225T000000  $180,000.00
# 3  2487200875  20141209T000000  $604,000.00
# 4  1954400510  20150218T000000  $510,000.00

# %%
### DEFINE ###
#"Unnamed: 0" column needs to be dropped.

### CLEAN ### 
#houseDf.drop(columns=["Unnamed: 0"], inplace=True)
houseDf.drop(columns=['Year Renovated'], inplace=True)
### TEST ###
houseDf.head()
# Out:
#            ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors Waterfront?  \
# 0  7129300520         3       1.00         1180    5650.0     1.0          No
# 1  6414100192         3       2.25         2570    7242.0     2.0          No
# 2  5631500400         2       1.00          770   10000.0     1.0          No
# 3  2487200875         4       3.00         1960    5000.0     1.0          No
# 4  1954400510         3       2.00         1680    8080.0     1.0          No
#
#         View  House Condition  Grade  SQFT above  SQFT basement  Year Built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %%
### DEFINE ###
#All columns need to be changed to snake case. 

### CLEAN ### 
houseDf.rename(columns={"ID":"id", "Bedrooms":"bedrooms", "Bathrooms":"bathrooms", "SQFT living":"sqft_living", "SQFT lot":"sqft_lot", "Floors":"floors", "Waterfront?":"waterfront", "View":"view", "House Condition":"house_condition", "Grade":"grade", "SQFT above":"sqft_above", "SQFT basement":"sqft_basement", "Year Built":"yr_built", "Zipcode":"zipcode", "Lat":"lat", "Long":"long", "SQFT living 15":"sqft_living_15", "SQFT lot 15":"sqft_lot_15"}, inplace=True)

### TEST ###
houseDf.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0  7129300520         3       1.00         1180    5650.0     1.0         No
# 1  6414100192         3       2.25         2570    7242.0     2.0         No
# 2  5631500400         2       1.00          770   10000.0     1.0         No
# 3  2487200875         4       3.00         1960    5000.0     1.0         No
# 4  1954400510         3       2.00         1680    8080.0     1.0         No
#
#         view  house_condition  grade  sqft_above  sqft_basement  yr_built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0    1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400    1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0    1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910    1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0    1987.0
#
#    zipcode      lat     long  sqft_living_15  sqft_lot_15
# ...

# %%
### DEFINE ###
#All columns need to be changed to snake case.

### CLEAN ### 
salesDf.rename(columns={"ID":"id", "DATE":"date", "Price":"price"}, inplace=True)

### TEST ###
salesDf.head()
# Out:
#            Id             date        price
# 0  7129300520  20141013T000000  $221,900.00
# 1  6414100192  20141209T000000  $538,000.00
# 2  5631500400  20150225T000000  $180,000.00
# 3  2487200875  20141209T000000  $604,000.00
# 4  1954400510  20150218T000000  $510,000.00

# %%
#For some reason the "I" in "ID" did not change to lower case, so I made another rename statement.
salesDf.rename(columns={"Id":"id"}, inplace=True)

salesDf.head()
# Out:
#            id             date        price
# 0  7129300520  20141013T000000  $221,900.00
# 1  6414100192  20141209T000000  $538,000.00
# 2  5631500400  20150225T000000  $180,000.00
# 3  2487200875  20141209T000000  $604,000.00
# 4  1954400510  20150218T000000  $510,000.00

# %%
### DEFINE ###
#The id column needs to be changed to string data type.

### CLEAN ### 
houseDf.id = houseDf.id.astype(str)

### TEST ###
print(houseDf['id'])
# Out:
# 0        7129300520
# 1        6414100192
# 2        5631500400
# 3        2487200875
# 4        1954400510
#             ...
# 21608     263000018
# 21609    6600060120
# 21610    1523300141
# 21611     291310100
# 21612    1523300157
# Name: id, Length: 21613, dtype: object

# %%
### DEFINE ###
#The zipcode column also needs to be changed to a string data type.

### CLEAN ### 
houseDf.zipcode = houseDf.zipcode.astype(str)

### TEST ###
print(houseDf['zipcode'])
# Out:
# 0        98178.0
# 1        98125.0
# 2        98028.0
# 3        98136.0
# 4        98074.0
#           ...
# 21608    98103.0
# 21609    98146.0
# 21610    98144.0
# 21611    98027.0
# 21612    98144.0
# Name: zipcode, Length: 21613, dtype: object

# %% [markdown]
# ### Step 3: Treat Missing Values

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
### DEFINE ###
# There are 2 missing values in the bathrooms column that need to be filled with the mean.

### CLEAN ### 
houseDf.bathrooms = houseDf.bathrooms.fillna(houseDf.bathrooms.mean())

### TEST ###
houseDf.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           2
# floors             0
# waterfront         8
# view               2
# house_condition    6
# grade              2
# sqft_above         1
# sqft_basement      0
# yr_built           1
# zipcode            3
# lat                1
# long               1
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
### DEFINE ###
#sqft_lot is missing 2 values which need to be filled with the mean.

### CLEAN ### 
houseDf.sqft_lot = houseDf.sqft_lot.fillna(houseDf.sqft_lot.mean())

### TEST ###
houseDf.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           0
# floors             0
# waterfront         8
# view               2
# house_condition    6
# grade              2
# sqft_above         1
# sqft_basement      0
# yr_built           1
# zipcode            3
# lat                1
# long               1
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
### DEFINE ###
#The missing values in the waterfront column need to be filled with the mode.

### CLEAN ### 
# waterfront_mode = houseDf[]


### TEST ###
houseDf.isna().sum()
# Out:
# id                     0
# bedrooms               0
# bathrooms              0
# sqft_living            0
# sqft_lot               0
# floors                 0
# waterfront         21613
# view                   2
# house_condition        6
# grade                  2
# sqft_above             1
# sqft_basement          0
# yr_built               1
# zipcode                0
# lat                    1
# long                   1
# sqft_living_15         0
# sqft_lot_15            0
# dtype: int64

# %%
### DEFINE ###
#The missing values in the condition column need to be filled with the mode.

### CLEAN ### 
condition_mode = houseDf['house_condition'].mode()

houseDf['house_condition'].fillna(value=condition_mode[0], inplace=True)

### TEST ###
houseDf.isna().sum()
# Out:
# id                     0
# bedrooms               0
# bathrooms              0
# sqft_living            0
# sqft_lot               0
# floors                 0
# waterfront         21613
# view                   2
# house_condition        0
# grade                  2
# sqft_above             1
# sqft_basement          0
# yr_built               1
# zipcode                0
# lat                    1
# long                   1
# sqft_living_15         0
# sqft_lot_15            0
# dtype: int64

# %%
### DEFINE ###
#The grade column has values that need to be filled with the mean.

### CLEAN ### 
houseDf['grade'] = houseDf['grade'].fillna(value=houseDf['grade'].mean())

### TEST ###
houseDf.isna().sum()
# Out:
# id                     0
# bedrooms               0
# bathrooms              0
# sqft_living            0
# sqft_lot               0
# floors                 0
# waterfront         21613
# view                   2
# house_condition        0
# grade                  0
# sqft_above             1
# sqft_basement          0
# yr_built               1
# zipcode                0
# lat                    1
# long                   1
# sqft_living_15         0
# sqft_lot_15            0
# dtype: int64

# %%
### DEFINE ###
#I accidentally deleted every single value in the waterfront column, so I am going to delete the column for this instance. Typically I would make another copy of the original data frame and restart.

### CLEAN ### 
houseDf.drop(columns=['waterfront'], inplace=True)

### TEST ###
houseDf.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           0
# floors             0
# view               2
# house_condition    0
# grade              0
# sqft_above         1
# sqft_basement      0
# yr_built           1
# zipcode            0
# lat                1
# long               1
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
### DEFINE ###
#Dropping other rows with missing values.

### CLEAN ### 
houseDf.dropna(axis=0, how='any', inplace=True)

### TEST ###
houseDf.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           0
# floors             0
# view               0
# house_condition    0
# grade              0
# sqft_above         0
# sqft_basement      0
# yr_built           0
# zipcode            0
# lat                0
# long               0
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
### DEFINE ###
#Delete rows in salesDf where price is null.

### CLEAN ### 
# salesDf.dropna(axis=0,how='any', inplace=True)

### TEST ###
salesDf.isna().sum()
# Out:
# id       0
# date     0
# price    0
# dtype: int64

# %% [markdown]
# ### Step 4: Treat Outliers

# %%
### The following have outliers: Bedrooms(Max 33), Bathrooms(max 10), SQFT lot(?),
# SQFT above(Max 12000), SQFT basement(Max 4800), Year Built(Min 1000, Max 2050), SQFT lot 15?

# %%
######################### TO DO ###################################
from scipy.stats import zscore
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
houseDf['bedrooms_zscore'] = zscore(houseDf['bedrooms'])

# %%
houseDf.query('bedrooms_zscore > 3 or bedrooms_zscore < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 16     1875500060        30       2.00         1890   14040.0     2.0
# 556    5486800070         7       3.50         4640   15235.0     2.0
# 875    6306400140         0       0.00         3064    4764.0     3.5
# 1135   4024100951         7       3.00         2940    8624.0     1.0
# 1241   7227802030         7       3.00         2800    9569.0     1.0
# ...           ...       ...        ...          ...       ...     ...
# 18975  1778360150         7       5.50         6630   13782.0     2.0
# 19254  8812401450        10       3.00         2920    3745.0     2.0
# 19302  3756900027         8       3.00         3840   15990.0     1.0
# 19327  2771604190         7       4.25         3670    4000.0     2.0
# 19452  3980300371         0       0.00          290   20875.0     1.0
#
#             view     house_condition  grade  sqft_above  sqft_basement  \
# ...

# %%
### DEFINE ###
# Rows need to be deleted that are outside of the threshold of 3

### CLEAN ### 
houseDf = houseDf.query('bedrooms_zscore < 3 and bedrooms_zscore > -3').copy()

### TEST ###
houseDf.query('bedrooms_zscore > 3 or bedrooms_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, view, house_condition, grade, sqft_above, sqft_basement, yr_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore]
# Index: []

# %%
houseDf.loc[houseDf.bathrooms > 7]
# Out:
#               id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 44    1432701230         3      10.00         1280    9656.0     1.0
# 7252  6762700020         6       8.00        12050   27600.0     2.5
# 9254  9208900037         6       7.75         9890   31374.0     2.0
#
#            view house_condition  grade  sqft_above  sqft_basement  yr_built  \
# 44    Very Poor  Good Condition    6.0       920.0            360    1959.0
# 7252       Good  Good Condition   13.0      8570.0           3480    1910.0
# 9254      Great    OK Condition   13.0      8860.0           1030    2001.0
#
#       zipcode      lat     long  sqft_living_15  sqft_lot_15  bedrooms_zscore
# 44    98058.0  47.4485 -122.175            1340         8808        -0.392996
# 7252  98102.0  47.6298 -122.323            3940         8800         2.773639
# 9254  98039.0  47.6305 -122.240            4540        42730         2.773639

# %%
houseDf['bathrooms_zscores'] = zscore(houseDf['bathrooms'])

# %%
houseDf.query('bathrooms_zscores > 9 or bathrooms_zscores < -3')
# Out:
#               id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 44    1432701230         3      10.00         1280    9656.0     1.0
# 7252  6762700020         6       8.00        12050   27600.0     2.5
# 8092  1924059029         5       6.75         9640   13068.0     1.0
# 9254  9208900037         6       7.75         9890   31374.0     2.0
#
#            view house_condition  grade  sqft_above  sqft_basement  yr_built  \
# 44    Very Poor  Good Condition    6.0       920.0            360    1959.0
# 7252       Good  Good Condition   13.0      8570.0           3480    1910.0
# 8092      Great    OK Condition   12.0      4820.0           4820    1983.0
# 9254      Great    OK Condition   13.0      8860.0           1030    2001.0
#
#       zipcode      lat     long  sqft_living_15  sqft_lot_15  bedrooms_zscore  \
# 44    98058.0  47.4485 -122.175            1340         8808        -0.392996
# 7252  98102.0  47.6298 -122.323            3940         8800         2.773639
# ...

# %%
### DEFINE ###
# Rows need to be deleted that are outside of the threshold of 9

### CLEAN ### 
houseDf = houseDf.query('bathrooms_zscores < 9 and bathrooms_zscores > -3').copy()

### TEST ###
houseDf.query('bathrooms_zscores > 9 or bathrooms_zscores < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, view, house_condition, grade, sqft_above, sqft_basement, yr_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscores]
# Index: []

# %%
houseDf['sqft_lot_zscores'] = zscore(houseDf['sqft_lot'])

# %%
houseDf.query('sqft_lot_zscores > 5 or sqft_lot_zscores < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 145    1526069017         4       2.50         3670  315374.0     2.0
# 527    3225079035         6       5.00         6050  230652.0     2.0
# 929    7937600830         4       3.00         2570  262018.0     1.0
# 1045   1825079070         3       1.75         1560  242629.0     1.0
# 1703   3121069036         3       1.75         3020  360241.0     2.0
# ...           ...       ...        ...          ...       ...     ...
# 20811  1825079046         3       2.50         1820  374616.0     2.0
# 20974  8835800450         3       2.50         2780  275033.0     1.0
# 21325  2826079027         3       2.50         3090  384634.0     2.0
# 21344  8835770170         5       6.00         6880  279968.0     2.0
# 21351  3421069049         2       1.75         1130  276170.0     1.0
#
#             view house_condition  grade  sqft_above  sqft_basement  yr_built  \
# ...

# %%
### DEFINE ###
# Rows need to be deleted that are outside sqft_lot threshold

### CLEAN ### 
houseDf = houseDf.query('sqft_lot_zscores < 5 and sqft_lot_zscores > -3').copy()

### TEST ###
houseDf.query('sqft_lot_zscores > 5 or sqft_lot_zscores < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, view, house_condition, grade, sqft_above, sqft_basement, yr_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscores, sqft_lot_zscores]
# Index: []

# %%
houseDf['sqft_above_zscores'] = zscore(houseDf['sqft_above'])
houseDf.query('sqft_above_zscores > 10 or sqft_above_zscores < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 19864  1776230060         4        2.5         2150    3143.0     2.0
#
#             view house_condition  grade  sqft_above  ...  yr_built  zipcode  \
# 19864  Very Poor    OK Condition    7.0     12542.0  ...    2010.0  98059.0
#
#            lat     long  sqft_living_15  sqft_lot_15  bedrooms_zscore  \
# 19864  47.5048 -122.154            2640         3200         0.662549
#
#        bathrooms_zscores  sqft_lot_zscores  sqft_above_zscores
# 19864           0.507986         -0.288654            13.11871
#
# [1 rows x 21 columns]

# %%
### DEFINE ###
# Rows need to be deleted that are above the threshold of 10

### CLEAN ### 
houseDf = houseDf.query('sqft_above_zscores < 10 and sqft_above_zscores > -3').copy()

### TEST ###
houseDf.query('sqft_above_zscores > 10 or sqft_above_zscores < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, view, house_condition, grade, sqft_above, sqft_basement, yr_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscores, sqft_lot_zscores, sqft_above_zscores]
# Index: []
#
# [0 rows x 21 columns]

# %%
houseDf['sqft_basement_zscores'] = zscore(houseDf['sqft_basement'])
houseDf.query('sqft_basement_zscores > 5 or sqft_basement_zscores < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 2088   4139420070         5       3.25         5180   19606.0     1.0
# 2125   4379600030         3       3.75         6400   76665.0     1.0
# 2236   4139420370         4       5.00         6055   21630.0     1.0
# 5049   7856410430         6       2.75         5700   20000.0     1.0
# 10085  7767000060         5       4.25         6510   16471.0     2.0
# 11829  4139420640         4       3.50         5490   14300.0     1.0
# 15049  8924600020         4       4.50         5770   10050.0     1.0
# 15482   624069108         4       3.25         7000   28206.0     1.0
# 19215  4131900042         5       4.25         6490   10862.0     2.0
#
#             view  house_condition  grade  sqft_above  ...  zipcode      lat  \
# 2088   Very Poor     OK Condition   11.0      2610.0  ...  98006.0  47.5550
# 2125     Neutral   Good Condition   10.0      3810.0  ...  98177.0  47.7313
# ...

# %%
### DEFINE ###
# Rows need to be deleted that are above the threshold of 5

### CLEAN ### 
houseDf = houseDf.query('sqft_basement_zscores < 5 and sqft_basement_zscores > -3').copy()

### TEST ###
houseDf.query('sqft_basement_zscores > 5 or sqft_basement_zscores < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, view, house_condition, grade, sqft_above, sqft_basement, yr_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscores, sqft_lot_zscores, sqft_above_zscores, sqft_basement_zscores]
# Index: []
#
# [0 rows x 22 columns]

# %%
houseDf['yr_built_zscores'] = zscore(houseDf['yr_built'])

# %%
houseDf.query('yr_built_zscores > 3 or yr_built_zscores < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 20981  3746700120         3       3.50         3940   11632.0     2.0
# 21270  1773100541         3       2.25         1580     920.0     3.0
#
#             view house_condition  grade  sqft_above  ...      lat     long  \
# 20981  Very Poor    OK Condition   10.0      3940.0  ...  47.4380 -122.344
# 21270  Very Poor    OK Condition    8.0      1580.0  ...  47.5578 -122.363
#
#       sqft_living_15  sqft_lot_15  bedrooms_zscore  bathrooms_zscores  \
# 20981           2015        11632        -0.392996           1.816077
# 21270           1250         1150        -0.392996           0.180963
#
#        sqft_lot_zscores  sqft_above_zscores  sqft_basement_zscores  \
# 20981         -0.083709            2.633122              -0.665242
# 21270         -0.342322           -0.243649              -0.665242
#
#        yr_built_zscores
# 20981        -32.232862
# 21270          2.635374
#
# [2 rows x 23 columns]

# %%
### DEFINE ###
# Rows need to be deleted that are above the threshold of 3

### CLEAN ### 
houseDf = houseDf.query('yr_built_zscores < 3 and yr_built_zscores > -3').copy()

### TEST ###
houseDf.query('yr_built_zscores > 3 or yr_built_zscores < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, view, house_condition, grade, sqft_above, sqft_basement, yr_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscores, sqft_lot_zscores, sqft_above_zscores, sqft_basement_zscores, yr_built_zscores]
# Index: []
#
# [0 rows x 23 columns]

# %%
houseDf['sqft_living_15_zscores'] = zscore(houseDf['sqft_living_15'])
houseDf.query('sqft_living_15_zscores > 3 or sqft_living_15_zscores < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 5      7237550310         4       4.50         5420  101930.0     1.0
# 21     2524049179         3       2.75         3050   44867.0     1.0
# 300    3225069065         4       5.00         4550   18641.0     1.0
# 384     713500030         5       3.50         4800   14984.0     2.0
# 431    2944010240         4       3.00         4040   19700.0     2.0
# ...           ...       ...        ...          ...       ...     ...
# 21254  7852120050         4       3.50         3510   10010.0     2.0
# 21258  2424059163         5       3.50         5430   10327.0     2.0
# 21375  6061500100         6       3.50         4310    7760.0     2.0
# 21540   715010530         5       3.50         4410   13000.0     2.0
# 21590  7430200100         4       3.50         4910    9444.0     1.5
#
#             view house_condition  grade  sqft_above  ...     long  \
# ...

# %%
### DEFINE ###
# Rows need to be deleted that are above the threshold of 3

### CLEAN ### 
houseDf = houseDf.query('sqft_living_15_zscores < 3 and sqft_living_15_zscores > -3').copy()

### TEST ###
houseDf.query('sqft_living_15_zscores > 3 or sqft_living_15_zscores < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, view, house_condition, grade, sqft_above, sqft_basement, yr_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscores, sqft_lot_zscores, sqft_above_zscores, sqft_basement_zscores, yr_built_zscores, sqft_living_15_zscores]
# Index: []
#
# [0 rows x 24 columns]

# %%
houseDf['sqft_lot_15_zscores'] = zscore(houseDf['sqft_lot_15'])
houseDf.query('sqft_lot_15_zscores > 3 or sqft_lot_15_zscores < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 3801   1550000463         4       3.50         3080  118918.0     2.0
# 8765    120069059         3       2.50         2920  169448.0     2.5
# 11183  1422029117         3       1.75         1640   53400.0     1.0
# 12669   619079061         4       2.00         2030  103672.0     1.0
# 15557  3623029034         3       1.00         1120   32250.0     1.0
# 15620  2225079030         2       1.00          960   87991.0     1.5
# 17659   620079042         2       1.00         2360  105850.0     1.0
# 18524  8807810090         3       1.00         1350   14212.0     1.0
# 21431  2725079018         4       3.25         3540  159430.0     2.0
#
#             view house_condition  grade  sqft_above  ...  sqft_living_15  \
# 3801   Very Poor    OK Condition    9.0      3080.0  ...            1830
# 8765   Very Poor    OK Condition    9.0      2920.0  ...            2360
# ...

# %%
### DEFINE ###
# Rows need to be deleted that are above the threshold of 3

### CLEAN ### 
houseDf = houseDf.query('sqft_lot_15_zscores < 3 and sqft_lot_15_zscores > -3').copy()

### TEST ###
houseDf.query('sqft_lot_15_zscores > 3 or sqft_lot_15_zscores < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, view, house_condition, grade, sqft_above, sqft_basement, yr_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscores, sqft_lot_zscores, sqft_above_zscores, sqft_basement_zscores, yr_built_zscores, sqft_living_15_zscores, sqft_lot_15_zscores]
# Index: []
#
# [0 rows x 25 columns]

# %%
from

# %%
### DEFINE ###
#Change the price column in the salesDf to be a float

### CLEAN ### 
salesDf['price'] = salesDf['price'].str.replace('$', '', regex=True)

salesDf['price'] = salesDf['price'].str.replace(',', '', regex=True).astype(float)


### TEST ###
print(salesDf['price'])
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21609, dtype: float64

# %%
salesDf.head()
# Out:
#            id             date        price
# 0  7129300520  20141013T000000  $221,900.00
# 1  6414100192  20141209T000000  $538,000.00
# 2  5631500400  20150225T000000  $180,000.00
# 3  2487200875  20141209T000000  $604,000.00
# 4  1954400510  20150218T000000  $510,000.00

# %%
salesDf['price_zscore'] = zscore(salesDf['price'])
salesDf.query('price_zscore > 6 or price_zscore < -3')
# Out:
#                id             date      price  price_zscore
# 269    7960900060  20150504T000000  2900000.0      6.428300
# 300    3225069065  20140624T000000  3075000.0      6.904986
# 656    3760500116  20141120T000000  3070000.0      6.891366
# 1164   1247600105  20141020T000000  5110800.0     12.450340
# 1315   7558700030  20150413T000000  5300000.0     12.965705
# ...           ...              ...        ...           ...
# 20460  9808100150  20150402T000000  3345000.0      7.640444
# 20535  1370800515  20141030T000000  2950000.0      6.564496
# 21040  6447300365  20141113T000000  2900000.0      6.428300
# 21530  8964800330  20150407T000000  3000000.0      6.700692
# 21576  9253900271  20150107T000000  3567000.0      8.245154
#
# [71 rows x 4 columns]

# %%
### DEFINE ###
# Rows need to be deleted that are above the threshold of 6

### CLEAN ### 
salesDf = salesDf.query('price_zscore < 6 and price_zscore > -3').copy()

### TEST ###
salesDf.query('price_zscore > 6 or price_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, date, price, price_zscore]
# Index: []

# %%
houseDf.isna().sum()
# Out:
# id                        0
# bedrooms                  0
# bathrooms                 0
# sqft_living               0
# sqft_lot                  0
# floors                    0
# view                      0
# house_condition           0
# grade                     0
# sqft_above                0
# sqft_basement             0
# yr_built                  0
# zipcode                   0
# lat                       0
# long                      0
# sqft_living_15            0
# sqft_lot_15               0
# bedrooms_zscore           0
# bathrooms_zscores         0
# sqft_lot_zscores          0
# sqft_above_zscores        0
# sqft_basement_zscores     0
# yr_built_zscores          0
# sqft_living_15_zscores    0
# sqft_lot_15_zscores       0
# dtype: int64

# %%
houseDf = houseDf.iloc[:,:17].copy()

# %%
houseDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20933 entries, 0 to 21612
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               20933 non-null  object
#  1   bedrooms         20933 non-null  int64
#  2   bathrooms        20933 non-null  float64
#  3   sqft_living      20933 non-null  int64
#  4   sqft_lot         20933 non-null  float64
#  5   floors           20933 non-null  float64
#  6   view             20933 non-null  object
#  7   house_condition  20933 non-null  object
#  8   grade            20933 non-null  float64
#  9   sqft_above       20933 non-null  float64
#  10  sqft_basement    20933 non-null  int64
#  11  yr_built         20933 non-null  float64
#  12  zipcode          20933 non-null  object
#  13  lat              20933 non-null  float64
#  14  long             20933 non-null  float64
#  15  sqft_living_15   20933 non-null  int64
# ...

# %%
salesDf = salesDf.iloc[:, :-1].copy()

# %%
salesDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21538 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      21538 non-null  int64
#  1   date    21538 non-null  object
#  2   price   21538 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 673.1+ KB

# %% [markdown]
# ### Step 5: Summarize Actions Taken & Justify Approach

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# #### Names / Values / Dtypes:
#
# - Dropped unnamed 0 column from both salesDf and houseDf
# - Made columns lower case and snake case
# - Changed id to string/object
# - Changed zipcode to string/object
# - Changed price to float
#
# This was done to improve the fluidity of the cleaning that was to be done in the next steps.
#
# #### Missing Values:
#
# HouseDf:
#
# - bathrooms - filled in with mean
# - sqft_lot - deleted rows with null values
# - view - deleted rows with null values
# - house_condition - filled in with mode
# - grade - filled in with mean
# - sqft_above - deleted rows with null values
# - year_built - deleted rows with null values
# - year_renovated - deleted entire column
# - zipcode - deleted rows with null values
# - lat - deleted rows with null values
# - long - deleted rows with null values
#
# SalesDf:
#
# - price - deleted rows where there are null values
#
#
#
# #### Outliers:
#
# HouseDf:
#
# - Bedrooms - removed outliers above the threshold of 3
# - Bathrooms - removed outliers above the threshold of 9
# - Sqft lot - removed outliers above the threshold of 5
# - SQFT above - removed outliers above the threshold of 10
# - Sqft basement - removed outliers above the threshold of 5
# - Year Built - removed outliers above the threshold of 3
# - Year Renovated - removed outliers above the threshold of 3
# - SQFT Living 15 - removed outliers above the threshold of 3
# - SQFT lot 15 - removed outliers above the threshold of 6
#
# SalesDf:
#
# - Price - removed outliers above the threshold of 3
#
# This was done to preserve the majority of the data. I did my best never to remove more than 1% of the rows.

# %% [markdown]
# ## Part 4: Re-Express Categorical Variables

# %% [markdown]
# ### Step 1: Determine Which Variables Need to Be Re-Expressed

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# List categorical variables which need to be re-expressed here:
#
# - View
# - House Condition
#
# Waterfront would have been re-expressed if I didn't delete all of the values.

# %% [markdown]
# ### Step 2: Choose Method to Re-Express Variables

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to explain which method you are choosing to re-express each variable and why.
#
# - View will be will be replaced with a 1-5 scale depending on the rating so that the machine can process the data and analyze it.
# - House Condition will be replaced with a 1-5 scale depending on the rating for the same purpose.

# %% [markdown]
# ### Step 3: Perform Transformation

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
houseDf.view.unique()
# Out:
# array(['Very Poor', 'Good', 'Neutral', 'Great', 'Poor'], dtype=object)

# %%
houseDf['view'] = houseDf['view'].replace({'Very Poor':1, 'Poor':2, 'Neutral':3, 'Good':4, 'Great':5}).astype(int)

# %%
houseDf.view.unique()
# Out:
# array([1, 4, 3, 5, 2])

# %%
houseDf.house_condition.unique()
# Out:
# array(['OK Condition', 'Great Condition', 'Good Condition',
#        'Very Bad Condition', 'Bad Condition'], dtype=object)

# %%
houseDf['house_condition'] = houseDf['house_condition'].replace({'Very Bad Condition':1, 'Bad Condition':2, 'OK Condition':3, 'Good Condition':4, 'Great Condition':5})

# %%
houseDf.house_condition.unique()
# Out:
# array([3, 5, 4, 1, 2])

# %% [markdown]
# ### Step 4: Summarize Actions Taken & Justify Approach

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# #### Actions Taken:
#
# - Replaced Poor-Great ratings with integers on a scale 1 to 5.
# - Replaced Poor Condition - Great condition ratings with integers on a scale 1 to 5.

# %% [markdown]
# ## Part 5: Combine Datasets into Master DataFrame

# %% [markdown]
# ### Step 1: Choose Method to Merge DataFrames into New Master DataFrame

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# #### Method:
#
# - I will merge using the .merge() method to make a more seamless merge.

# %% [markdown]
# ### Step 2: Merge DataFrames

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
salesDf['id'] = salesDf['id'].astype(str)

# %%
master_df = salesDf.merge(houseDf, on="id")

# %%
# Use .head() method to print first few rows of new master dataframe
master_df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  view  house_condition  grade  sqft_above  sqft_basement  \
# 0    5650.0     1.0     1                3    7.0      1180.0              0
# 1    7242.0     2.0     1                3    7.0      2170.0            400
# 2   10000.0     1.0     1                3    6.0       770.0              0
# 3    5000.0     1.0     1                5    7.0      1050.0            910
# 4    8080.0     1.0     1                3    8.0      1680.0              0
#
# ...

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21259 entries, 0 to 21258
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21259 non-null  object
#  1   date             21259 non-null  object
#  2   price            21259 non-null  float64
#  3   bedrooms         21259 non-null  int64
#  4   bathrooms        21259 non-null  float64
#  5   sqft_living      21259 non-null  int64
#  6   sqft_lot         21259 non-null  float64
#  7   floors           21259 non-null  float64
#  8   view             21259 non-null  int64
#  9   house_condition  21259 non-null  int64
#  10  grade            21259 non-null  float64
#  11  sqft_above       21259 non-null  float64
#  12  sqft_basement    21259 non-null  int64
#  13  yr_built         21259 non-null  float64
#  14  zipcode          21259 non-null  object
#  15  lat              21259 non-null  float64
# ...

# %% [markdown]
# ### Step 3: Save Master DataFrame to New .CSV

# %%
######################### TO DO ###################################
master_df.to_csv('master_df.csv', index=False)
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# ### Step 4: Push to GitHub / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.

# %% [markdown]
# ### Step 5: Record Brief Code Walkthrough / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.
